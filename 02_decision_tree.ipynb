# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('house_price.csv')
df.head()
# Out:
#      area  bedrooms  bathrooms       city    price
# 0  1200.0       2.0        2.0    Pokhara  4500000
# 1  1500.0       NaN        3.0  Kathmandu  6500000
# 2  1800.0       3.0        2.0    Chitwan  5200000
# 3  2200.0       4.0        3.0    Pokhara  7500000
# 4   950.0       2.0        1.0     Butwal  3200000

# %%
import math
median_area = math.floor(df.area.median())
median_bedrooms = math.floor(df.bedrooms.median())
median_bathrooms = math.floor(df.bathrooms.median())

# %%
df.area = df.area.fillna(median_area)
df.bedrooms = df.bedrooms.fillna(median_bedrooms)
df.bathrooms = df.bathrooms.fillna(median_bathrooms)

# %%
dummy = pd.get_dummies(df.city, dtype=int)

# %%
merged = pd.concat([df,dummy],axis='columns')
merged
# Out:
#       area  bedrooms  bathrooms       city    price  Butwal  Chitwan  \
# 0   1200.0       2.0        2.0    Pokhara  4500000       0        0
# 1   1500.0       3.0        3.0  Kathmandu  6500000       0        0
# 2   1800.0       3.0        2.0    Chitwan  5200000       0        1
# 3   2200.0       4.0        3.0    Pokhara  7500000       0        0
# 4    950.0       2.0        1.0     Butwal  3200000       1        0
# 5   1300.0       3.0        2.0  Kathmandu  5800000       0        0
# 6   1700.0       3.0        2.0    Pokhara  6100000       0        0
# 7   2000.0       4.0        3.0    Chitwan  6900000       0        1
# 8   1100.0       2.0        2.0     Butwal  3900000       1        0
# 9   2500.0       5.0        4.0  Kathmandu  9800000       0        0
# 10  1400.0       3.0        2.0    Pokhara  5400000       0        0
# 11  1600.0       3.0        2.0     Butwal  5100000       1        0
# 12  1900.0       4.0        3.0  Kathmandu  7300000       0        0
# 13  2100.0       3.0        3.0    Pokhara  7700000       0        0
# 14  1250.0       2.0        2.0    Chitwan  4700000       0        1
# 15  1450.0       3.0        2.0     Butwal  4950000       1        0
# 16  1750.0       3.0        3.0  Kathmandu  6700000       0        0
# 17  2300.0       4.0        4.0    Pokhara  8500000       0        0
# 18  1000.0       2.0        1.0    Chitwan  3500000       0        1
# 19  1550.0       3.0        2.0     Butwal  5300000       1        0
# 20  1600.0       4.0        3.0  Kathmandu  7200000       0        0
# 21  1350.0       2.0        2.0    Pokhara  5000000       0        0
# 22  1850.0       4.0        3.0    Chitwan  6400000       0        1
# 23  2400.0       5.0        4.0  Kathmandu  9400000       0        0
# 24  1150.0       2.0        2.0     Butwal  3700000       1        0
# 25  1650.0       3.0        2.0    Pokhara  6000000       0        0
# 26  1950.0       4.0        3.0  Kathmandu  7600000       0        0
# 27  2250.0       4.0        4.0    Chitwan  8100000       0        1
# 28  1050.0       2.0        1.0    Pokhara  3800000       0        0
# 29  1500.0       3.0        2.0     Butwal  5200000       1        0
#
#     Kathmandu  Pokhara
# 0           0        1
# 1           1        0
# 2           0        0
# 3           0        1
# 4           0        0
# 5           1        0
# 6           0        1
# 7           0        0
# 8           0        0
# 9           1        0
# 10          0        1
# 11          0        0
# 12          1        0
# 13          0        1
# 14          0        0
# 15          0        0
# 16          1        0
# 17          0        1
# 18          0        0
# 19          0        0
# 20          1        0
# 21          0        1
# 22          0        0
# 23          1        0
# 24          0        0
# 25          0        1
# 26          1        0
# 27          0        0
# 28          0        1
# 29          0        0

# %%
merged = merged.drop(merged[['city','Chitwan']],axis='columns')

# %%
merged.head()
# Out:
#      area  bedrooms  bathrooms    price  Butwal  Kathmandu  Pokhara
# 0  1200.0       2.0        2.0  4500000       0          0        1
# 1  1500.0       3.0        3.0  6500000       0          1        0
# 2  1800.0       3.0        2.0  5200000       0          0        0
# 3  2200.0       4.0        3.0  7500000       0          0        1
# 4   950.0       2.0        1.0  3200000       1          0        0

# %%
X = merged.drop(merged[['price']],axis='columns')
y = merged.price

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
model = DecisionTreeRegressor()

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,confusion_matrix
print("R2 score:",model.score(X_test,y_test))
print("MSE:",mean_squared_error(y_test,y_pred))
print("MAS:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score: 0.7748037249390485
# MSE: 524375000000.0
# MAS: 595833.3333333334

# %%
import seaborn as sns

# %%
sns.heatmap(merged.corr(),annot=True)
plt.savefig("heatmap.png")
